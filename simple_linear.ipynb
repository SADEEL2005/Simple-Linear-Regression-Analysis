# %% [markdown]
# <a href="https://colab.research.google.com/github/SADEEL2005/Simple-Linear-Regression-Analysis/blob/main/simple_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df=pd.read_csv('data.csv')
x=df.iloc[:,[0]].values
y=df.iloc[:,1].values
print(x)
print(y)
# Out:
# [[74.12846144]
#  [39.70572468]
#  [ 1.32720297]
#  [86.75245092]
#  [32.8038249 ]
#  [82.20309045]
#  [43.32555856]
#  [15.79332255]
#  [50.54491745]
#  [45.90227853]
#  [91.79202039]
#  [93.96474143]
#  [29.39041884]
#  [29.63006249]
#  [48.90763457]
#  [31.51920086]
#  [86.6123456 ]
#  [19.71276183]
#  [47.94188058]
#  [ 8.60975311]
#  [57.57203892]
#  [98.95354083]
#  [38.56225291]
#  [74.30565993]
#  [43.66575695]
#  [52.86819351]
#  [56.80816402]
#  [65.59779675]
#  [61.65943183]
#  [83.19557709]
#  [76.22499325]
#  [ 8.41487251]
#  [14.57271931]
#  [90.97054576]
#  [82.13505764]
#  [64.96730925]
#  [ 0.83166031]
#  [69.47349231]
#  [61.58364063]
#  [94.3033006 ]
#  [24.76147405]
#  [45.24717965]
#  [26.78673118]
#  [21.79301596]
#  [12.01542991]
#  [58.22703233]
#  [ 3.26382937]
#  [89.17689589]
#  [79.36322097]
#  [59.92632498]
#  [99.8168565 ]
#  [29.14280489]
#  [23.78000238]
#  [53.1606307 ]
#  [99.6449443 ]
#  [81.68865788]
#  [41.65275699]
#  [31.77178477]
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
plt.scatter(x_train,y_train,color='red')
plt.title('Train_group')
plt.xlabel('Years')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_train,regressor.predict(x_train),color='red')
plt.plot(x_train,regressor.predict(x_train),color='yellow')
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_pred,color='yellow')
plt.show()

# %%
r2=metrics.r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.7113565037713703
